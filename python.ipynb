# %%
a = 100
b = 14
ch1 = "Good luck!"
ch2 = "May the force be with you."
L1 =  [ "1", "2", "AA"]
L2 = [5, 9, 3, 8, 7]
dic1 = {"Python": 16, "Algorithmique": 19, "Mathématique": 11}

print(ch2, ch1)
"/".join(L1)
L2.insert(3, 14)
print(L2)
L2.sort()
print(L2)
print(ch1.upper())
ch3 = ch2[8:13]
print(ch3)
sum(L2)
[x * 2 for x in L2]
# Out:
# May the force be with you. Good luck!
# [5, 9, 3, 14, 8, 7]
# [3, 5, 7, 8, 9, 14]
# GOOD LUCK!
# force
# [6, 10, 14, 16, 18, 28]
